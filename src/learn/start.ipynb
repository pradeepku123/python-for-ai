# %%
print('Hello World')
# Out:
# Hello World

# %%
print(1,'HEllo World',890,sep='--',end='\t')
print(1,'HEllo World',891,sep='--')
# Out:
# 1--HEllo World--890	1--HEllo World--891

# %% [markdown]
# Data type

# %%
#Integers
print(344)
type(344)
# Out:
# 344
# int

# %%
#float
print(3.44)
type(3.44)
# Out:
# 3.44
# float

# %%
# Boolean
print(True)
type(True)
# Out:
# True
# bool

# %%
#Text/String
print('Hello World')
type('Hello World')
# Out:
# Hello World
# str

# %%
#list
print([2,'22'])
type([2,'22'])
# Out:
# [2, '22']
# list

# %%
#tuple
print((2,'22'))
type((2,'22'))
# Out:
# (2, '22')
# tuple

# %%
#Sets
print({2,'22'})
type({2,'22'})
# Out:
# {2, '22'}
# set

# %%
#Dictionary
print({2:'22'})
type({2:'22'})
# Out:
# {2: '22'}
# dict

# %%
# creating a variable diffrent style
a=1
b=3
c=4
print(a+b+c)

d,e,f=1,3,4
print(d+e+f)

# assingning same value to multiple variable
a=b=c=d=6

print(a,b,c,d)
# Out:
# 8
# 8
# 6 6 6 6
